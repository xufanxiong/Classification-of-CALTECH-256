# %%
import keras
from keras.applications import DenseNet201 #DenseNet121, DenseNet169, DenseNet201, ResNet50
from keras.models import Model
from keras.layers import Dense
from keras.regularizers import l2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from label2onehot import label2onehot
from onehot2label import onehot2label
from label_dict import label_dict
import gc
# Out:
# /opt/conda/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Use GPU
config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 4}, log_device_placement=True ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)

# %%
#Import train set
x = np.load('train_crop.npy')/255.
y_label = np.load('train.npy')

# %%
#Convert label to onehot
#onehot_y = label2onehot(y[:, 0], 256)
#np.save('onehot_y_train.npy',onehot_y)
#from keras.utils.np_utils import to_categorical
#y = to_categorical(y_label[:,0], num_classes=256)
y = y_label[:,0]

# %%
#Build the new model based on DenseNet121
def getmodel(num_classes=256):
    '''
    Build the new model based on DenseNet121, DenseNet169, DenseNet201
    
    Argument:
    num_classes -- (int) number of classes
    
    Return:
    model -- the new compiled model
    '''
    
    orig_model = DenseNet201(include_top=False, weights='imagenet', pooling='avg', classes=num_classes)
    densenet_out = orig_model.layers[-1].output
    out = Dense(256, activation='softmax', kernel_initializer='glorot_uniform')(densenet_out)
    model = Model(input=orig_model.input, output=out)
    model.compile(loss= "sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    
    return model

# %%
densemodel = getmodel(256)
# checkpoint
from keras.callbacks import ModelCheckpoint
filepath="DenseNet201_transfer_crop.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True,mode='max')
callbacks_list = [checkpoint]
history = densemodel.fit(x, y, epochs=15, batch_size=32, validation_split=0.25, callbacks=callbacks_list)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
#   app.launch_new_instance()
# Train on 17868 samples, validate on 5956 samples
# Epoch 1/15
# 17868/17868 [==============================] - 355s 20ms/step - loss: 3.2508 - acc: 0.3184 - val_loss: 3.3676 - val_acc: 0.3487
#
# Epoch 00001: val_acc improved from -inf to 0.34872, saving model to DenseNet201_transfer_crop.hdf5
# Epoch 2/15
# 17868/17868 [==============================] - 328s 18ms/step - loss: 1.8371 - acc: 0.5603 - val_loss: 2.8002 - val_acc: 0.4480
#
# Epoch 00002: val_acc improved from 0.34872 to 0.44795, saving model to DenseNet201_transfer_crop.hdf5
# Epoch 3/15
# 17868/17868 [==============================] - 329s 18ms/step - loss: 1.3003 - acc: 0.6754 - val_loss: 2.5347 - val_acc: 0.4520
#
# Epoch 00003: val_acc improved from 0.44795 to 0.45198, saving model to DenseNet201_transfer_crop.hdf5
# Epoch 4/15
# 17868/17868 [==============================] - 332s 19ms/step - loss: 0.9441 - acc: 0.7471 - val_loss: 2.6537 - val_acc: 0.4856
#
# Epoch 00004: val_acc improved from 0.45198 to 0.48556, saving model to DenseNet201_transfer_crop.hdf5
# Epoch 5/15
# 17868/17868 [==============================] - 333s 19ms/step - loss: 0.6695 - acc: 0.8133 - val_loss: 3.7959 - val_acc: 0.3919
#
# Epoch 00005: val_acc did not improve
# Epoch 6/15
# 17868/17868 [==============================] - 333s 19ms/step - loss: 0.4972 - acc: 0.8568 - val_loss: 2.4950 - val_acc: 0.5287
#
# Epoch 00006: val_acc improved from 0.48556 to 0.52871, saving model to DenseNet201_transfer_crop.hdf5
# Epoch 7/15
# 17868/17868 [==============================] - 332s 19ms/step - loss: 0.3407 - acc: 0.8997 - val_loss: 2.7630 - val_acc: 0.5000
#
# Epoch 00007: val_acc did not improve
# Epoch 8/15
# 17868/17868 [==============================] - 333s 19ms/step - loss: 0.2963 - acc: 0.9139 - val_loss: 2.9766 - val_acc: 0.5289
#
# Epoch 00008: val_acc improved from 0.52871 to 0.52888, saving model to DenseNet201_transfer_crop.hdf5
# Epoch 9/15
# 17868/17868 [==============================] - 332s 19ms/step - loss: 0.3091 - acc: 0.9086 - val_loss: 2.8166 - val_acc: 0.5297
#
# Epoch 00009: val_acc improved from 0.52888 to 0.52972, saving model to DenseNet201_transfer_crop.hdf5
# Epoch 10/15
# 17868/17868 [==============================] - 335s 19ms/step - loss: 0.2529 - acc: 0.9251 - val_loss: 3.4080 - val_acc: 0.4956
#
# Epoch 00010: val_acc did not improve
# Epoch 11/15
# 17868/17868 [==============================] - 333s 19ms/step - loss: 0.1956 - acc: 0.9414 - val_loss: 2.7238 - val_acc: 0.5707
#
# Epoch 00011: val_acc improved from 0.52972 to 0.57069, saving model to DenseNet201_transfer_crop.hdf5
# Epoch 12/15
# 17868/17868 [==============================] - 333s 19ms/step - loss: 0.1953 - acc: 0.9383 - val_loss: 3.4210 - val_acc: 0.5107
#
# Epoch 00012: val_acc did not improve
# Epoch 13/15
# 17868/17868 [==============================] - 333s 19ms/step - loss: 0.2203 - acc: 0.9341 - val_loss: 2.9671 - val_acc: 0.5403
#
# Epoch 00013: val_acc did not improve
# Epoch 14/15
# 17868/17868 [==============================] - 332s 19ms/step - loss: 0.1729 - acc: 0.9472 - val_loss: 3.4096 - val_acc: 0.5238
#
# Epoch 00014: val_acc did not improve
# Epoch 15/15
# 17868/17868 [==============================] - 331s 19ms/step - loss: 0.1595 - acc: 0.9521 - val_loss: 2.9254 - val_acc: 0.5473
#
# Epoch 00015: val_acc did not improve

# %%
#release RAM
del x, y
gc.collect()
# Out:
# 21888

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Import test dataset
X_test = np.load('test_crop.npy')/255.
Y_test = np.load('onehot_y_test.npy')
y_test = np.load('test.npy')

# %%
##Convert label to onehot
#y_test = label2onehot(Y_test[:, 0], 256)
#np.save('onehot_y_test.npy', y_test)

# %%
densemodel.load_weights('DenseNet201_transfer_crop.hdf5')

# %%
#evaluate
eva = densemodel.evaluate(X_test, y_test[:, 0], batch_size=32, verbose=1, sample_weight=None)
print()
print("Loss = " + str(eva[0]))
print("Test Accuracy = " + str(eva[1]))
# Out:
# 5956/5956 [==============================] - 40s 7ms/step
# ()
# Loss = 2.6674221184847737
# Test Accuracy = 0.5649764942914708

# %%
#predict a new image
predict_num = 1111
dict_label = label_dict()
X_predict = X_test[predict_num]
print('This image is: ' + dict_label[y_test[:, 0][predict_num]+1])
print('The dict_label of image is: '+str(y_test[:, 0][predict_num]+1))
plt.imshow(X_predict)
# Out:
# This image is: diamond-ring
# The dict_label of image is: 54

# %%
#predict
predict_vector = densemodel.predict(np.expand_dims(X_predict, axis=0))
index = np.where(predict_vector[0] == np.max(predict_vector[0]))
print('The predict dict_label of image is: '+str(index[0][0]+1))
print('The predict probability of image is: '+str(predict_vector[0, index[0][0]]))
print('This image is: ' + dict_label[index[0][0] + 1])
# Out:
# The predict dict_label of image is: 54
# The predict probability of image is: 0.9999769
# This image is: diamond-ring
