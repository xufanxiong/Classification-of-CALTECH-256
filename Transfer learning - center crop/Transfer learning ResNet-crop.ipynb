# %%
import keras
from keras.applications import ResNet50 #DenseNet121, DenseNet169, DenseNet201, ResNet50
from keras.models import Model
from keras.layers import Dense
from keras.regularizers import l2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from label2onehot import label2onehot
from onehot2label import onehot2label
from label_dict import label_dict
import gc
# Out:
# /opt/conda/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Use GPU
config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 4}, log_device_placement=True ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)

# %%
#Import train set
x = np.load('train_crop.npy')/255.
y_label = np.load('train.npy')

# %%
#Convert label to onehot
#onehot_y = label2onehot(y[:, 0], 256)
#np.save('onehot_y_train.npy',onehot_y)
#from keras.utils.np_utils import to_categorical
#y = to_categorical(y_label[:,0], num_classes=256)
y = y_label[:,0]

# %%
#Build the new model based on DenseNet121
def getmodel(num_classes=256):
    '''
    Build the new model based on DenseNet121, DenseNet169, DenseNet201
    
    Argument:
    num_classes -- (int) number of classes
    
    Return:
    model -- the new compiled model
    '''
    
    orig_model = ResNet50(include_top=False, weights='imagenet', pooling='avg', classes=num_classes)
    densenet_out = orig_model.layers[-1].output
    out = Dense(256, activation='softmax', kernel_initializer='glorot_uniform')(densenet_out)
    model = Model(input=orig_model.input, output=out)
    model.compile(loss= "sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    
    return model

# %%
densemodel = getmodel(256)
# checkpoint
from keras.callbacks import ModelCheckpoint
filepath="ResNet50_transfer_crop.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True,mode='max')
callbacks_list = [checkpoint]
history = densemodel.fit(x, y, epochs=15, batch_size=32, validation_split=0.25, callbacks=callbacks_list)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
#   app.launch_new_instance()
# Train on 17868 samples, validate on 5956 samples
# Epoch 1/15
# 17868/17868 [==============================] - 200s 11ms/step - loss: 4.0783 - acc: 0.1903 - val_loss: 4.2400 - val_acc: 0.1566
#
# Epoch 00001: val_acc improved from -inf to 0.15665, saving model to ResNet50_transfer_crop.hdf5
# Epoch 2/15
# 17868/17868 [==============================] - 188s 11ms/step - loss: 2.4472 - acc: 0.4371 - val_loss: 3.6634 - val_acc: 0.2671
#
# Epoch 00002: val_acc improved from 0.15665 to 0.26713, saving model to ResNet50_transfer_crop.hdf5
# Epoch 3/15
# 17868/17868 [==============================] - 186s 10ms/step - loss: 1.6866 - acc: 0.5826 - val_loss: 2.9580 - val_acc: 0.3808
#
# Epoch 00003: val_acc improved from 0.26713 to 0.38079, saving model to ResNet50_transfer_crop.hdf5
# Epoch 4/15
# 17868/17868 [==============================] - 183s 10ms/step - loss: 1.1025 - acc: 0.7180 - val_loss: 2.5894 - val_acc: 0.4542
#
# Epoch 00004: val_acc improved from 0.38079 to 0.45416, saving model to ResNet50_transfer_crop.hdf5
# Epoch 5/15
# 17868/17868 [==============================] - 182s 10ms/step - loss: 0.6631 - acc: 0.8219 - val_loss: 2.6867 - val_acc: 0.4785
#
# Epoch 00005: val_acc improved from 0.45416 to 0.47851, saving model to ResNet50_transfer_crop.hdf5
# Epoch 6/15
# 17868/17868 [==============================] - 182s 10ms/step - loss: 0.3737 - acc: 0.8972 - val_loss: 3.7792 - val_acc: 0.3648
#
# Epoch 00006: val_acc did not improve
# Epoch 7/15
# 17868/17868 [==============================] - 183s 10ms/step - loss: 0.2452 - acc: 0.9312 - val_loss: 3.1750 - val_acc: 0.4098
#
# Epoch 00007: val_acc did not improve
# Epoch 8/15
# 17868/17868 [==============================] - 183s 10ms/step - loss: 0.1814 - acc: 0.9500 - val_loss: 2.7338 - val_acc: 0.4982
#
# Epoch 00008: val_acc improved from 0.47851 to 0.49815, saving model to ResNet50_transfer_crop.hdf5
# Epoch 9/15
# 17868/17868 [==============================] - 184s 10ms/step - loss: 0.1572 - acc: 0.9575 - val_loss: 2.7170 - val_acc: 0.5178
#
# Epoch 00009: val_acc improved from 0.49815 to 0.51780, saving model to ResNet50_transfer_crop.hdf5
# Epoch 10/15
# 17868/17868 [==============================] - 184s 10ms/step - loss: 0.1546 - acc: 0.9552 - val_loss: 3.7168 - val_acc: 0.4130
#
# Epoch 00010: val_acc did not improve
# Epoch 11/15
# 17868/17868 [==============================] - 184s 10ms/step - loss: 0.1171 - acc: 0.9688 - val_loss: 2.5592 - val_acc: 0.5285
#
# Epoch 00011: val_acc improved from 0.51780 to 0.52854, saving model to ResNet50_transfer_crop.hdf5
# Epoch 12/15
# 17868/17868 [==============================] - 183s 10ms/step - loss: 0.1114 - acc: 0.9692 - val_loss: 2.8591 - val_acc: 0.5037
#
# Epoch 00012: val_acc did not improve
# Epoch 13/15
# 17868/17868 [==============================] - 184s 10ms/step - loss: 0.1160 - acc: 0.9677 - val_loss: 2.9042 - val_acc: 0.4901
#
# Epoch 00013: val_acc did not improve
# Epoch 14/15
# 17868/17868 [==============================] - 183s 10ms/step - loss: 0.0937 - acc: 0.9741 - val_loss: 2.6487 - val_acc: 0.5319
#
# Epoch 00014: val_acc improved from 0.52854 to 0.53190, saving model to ResNet50_transfer_crop.hdf5
# Epoch 15/15
# 17868/17868 [==============================] - 185s 10ms/step - loss: 0.0921 - acc: 0.9743 - val_loss: 3.0249 - val_acc: 0.5008
#
# Epoch 00015: val_acc did not improve

# %%
#release RAM
del x, y
gc.collect()
# Out:
# 7828

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Import test dataset
X_test = np.load('test_crop.npy')/255.
Y_test = np.load('onehot_y_test.npy')
y_test = np.load('test.npy')

# %%
##Convert label to onehot
#y_test = label2onehot(Y_test[:, 0], 256)
#np.save('onehot_y_test.npy', y_test)

# %%
densemodel.load_weights('ResNet50_transfer_crop.hdf5')

# %%
#evaluate
eva = densemodel.evaluate(X_test, y_test[:, 0], batch_size=32, verbose=1, sample_weight=None)
print()
print("Loss = " + str(eva[0]))
print("Test Accuracy = " + str(eva[1]))
# Out:
# 5956/5956 [==============================] - 24s 4ms/step
# ()
# Loss = 2.6026759256525596
# Test Accuracy = 0.5399597044996642

# %%
#predict a new image
predict_num = 1111
dict_label = label_dict()
X_predict = X_test[predict_num]
print('This image is: ' + dict_label[y_test[:, 0][predict_num]+1])
print('The dict_label of image is: '+str(y_test[:, 0][predict_num]+1))
plt.imshow(X_predict)
# Out:
# This image is: diamond-ring
# The dict_label of image is: 54

# %%
#predict
predict_vector = densemodel.predict(np.expand_dims(X_predict, axis=0))
index = np.where(predict_vector[0] == np.max(predict_vector[0]))
print('The predict dict_label of image is: '+str(index[0][0]+1))
print('The predict probability of image is: '+str(predict_vector[0, index[0][0]]))
print('This image is: ' + dict_label[index[0][0] + 1])
# Out:
# The predict dict_label of image is: 54
# The predict probability of image is: 0.99430144
# This image is: diamond-ring
