# %%
import numpy as np
import glob
import time
import cv2
import matplotlib.pyplot as plt

# %%
def dataset(path = '/datasets/Caltech256'):
    '''
    Import dataset. (Need to import numpy, glob, time, cv2)
    
    Arguments:
    path --
    
    Returns:
    list_data --
    '''
    
    all_data = glob.glob(path + '/256_ObjectCategories/*')
    all_data.sort()
    
    list_data = []
    class_num = len(all_data) - 1
    for i in range(class_num):
        data_eve_class = glob.glob(all_data[i] + '/*')
        tic = time.time()
        for j in range(len(data_eve_class)):
            img = cv2.imread(data_eve_class[j])
            list_data.append([i, img])
        toc = time.time()
        print('Import NO. ' + str(i + 1) + ' class use ' + str((toc-tic)*1000) + 'ms')
            
    return list_data

# %%
def label_dict(path = '/datasets/Caltech256'):
    '''
    To build a dict to record the label
    (need to import glob package)
    Arguments:
    path --
    
    Returns:
    dict_l --
    '''
    all_label = glob.glob(path + '/256_ObjectCategories/*')
    all_label.sort()
    
    dict_l = {}
    class_num = len(all_label) - 1
    for i in range(class_num):
        dict_l[i] = all_label[i].split('.')[-1]
    
    return dict_l

# %%
dict_label = label_dict()
data_set = dataset()
# Out:
# Import NO. 1 class use 410.094976425ms
# Import NO. 2 class use 327.744007111ms
# Import NO. 3 class use 550.354003906ms
# Import NO. 4 class use 398.543119431ms
# Import NO. 5 class use 396.296977997ms
# Import NO. 6 class use 363.983154297ms
# Import NO. 7 class use 379.342079163ms
# Import NO. 8 class use 788.596868515ms
# Import NO. 9 class use 1148.45895767ms
# Import NO. 10 class use 411.9181633ms
# Import NO. 11 class use 1033.56194496ms
# Import NO. 12 class use 579.404115677ms
# Import NO. 13 class use 764.429092407ms
# Import NO. 14 class use 300.218105316ms
# Import NO. 15 class use 323.333024979ms
# Import NO. 16 class use 287.410020828ms
# Import NO. 17 class use 324.737787247ms
# Import NO. 18 class use 304.470062256ms
# Import NO. 19 class use 374.222993851ms
# Import NO. 20 class use 199.97382164ms
# Import NO. 21 class use 305.425882339ms
# Import NO. 22 class use 312.345981598ms
# Import NO. 23 class use 957.828998566ms
# Import NO. 24 class use 1276.09610558ms
# Import NO. 25 class use 1619.95506287ms
# Import NO. 26 class use 1470.72601318ms
# Import NO. 27 class use 339.959859848ms
# Import NO. 28 class use 1180.30595779ms
# Import NO. 29 class use 1416.32008553ms
# Import NO. 30 class use 963.973045349ms
# Import NO. 31 class use 291.663885117ms
# Import NO. 32 class use 404.469013214ms
# Import NO. 33 class use 438.137054443ms
# Import NO. 34 class use 586.972951889ms
# Import NO. 35 class use 501.696825027ms
# Import NO. 36 class use 291.895866394ms
# Import NO. 37 class use 495.543956757ms
# Import NO. 38 class use 640.794992447ms
# Import NO. 39 class use 310.704946518ms
# Import NO. 40 class use 392.016887665ms
# Import NO. 41 class use 439.666032791ms
# Import NO. 42 class use 295.480966568ms
# Import NO. 43 class use 1548.27189445ms
# Import NO. 44 class use 550.330162048ms
# Import NO. 45 class use 348.489046097ms
# Import NO. 46 class use 403.249979019ms
# Import NO. 47 class use 216.940164566ms
# Import NO. 48 class use 378.45993042ms
# Import NO. 49 class use 1365.3960228ms
# Import NO. 50 class use 694.068193436ms
# Import NO. 51 class use 447.618961334ms
# Import NO. 52 class use 327.459096909ms
# Import NO. 53 class use 263.705968857ms
# Import NO. 54 class use 528.541088104ms
# Import NO. 55 class use 756.260156631ms
# Import NO. 56 class use 504.009008408ms
# Import NO. 57 class use 403.99813652ms
# Import NO. 58 class use 624.001979828ms
# Import NO. 59 class use 254.85086441ms
# Import NO. 60 class use 716.066122055ms
# Import NO. 61 class use 327.054977417ms
# Import NO. 62 class use 379.415988922ms
# Import NO. 63 class use 272.372961044ms
# Import NO. 64 class use 693.380117416ms
# Import NO. 65 class use 768.526077271ms
# Import NO. 66 class use 223.318815231ms
# Import NO. 67 class use 219.507932663ms
# Import NO. 68 class use 1239.05396461ms
# Import NO. 69 class use 450.54602623ms
# Import NO. 70 class use 413.761854172ms
# Import NO. 71 class use 627.825975418ms
# Import NO. 72 class use 1041.74804688ms
# Import NO. 73 class use 1243.99805069ms
# Import NO. 74 class use 640.547990799ms
# Import NO. 75 class use 353.149175644ms
# Import NO. 76 class use 261.50894165ms
# Import NO. 77 class use 502.434968948ms
# Import NO. 78 class use 460.532903671ms
# Import NO. 79 class use 558.993816376ms
# Import NO. 80 class use 1147.38607407ms
# Import NO. 81 class use 265.439033508ms
# Import NO. 82 class use 882.694959641ms
# Import NO. 83 class use 866.273880005ms
# Import NO. 84 class use 425.879955292ms
# Import NO. 85 class use 1053.43985558ms
# Import NO. 86 class use 521.60692215ms
# Import NO. 87 class use 832.760095596ms
# Import NO. 88 class use 621.114969254ms
# Import NO. 89 class use 1149.55210686ms
# Import NO. 90 class use 1061.56992912ms
# Import NO. 91 class use 318.053007126ms
# Import NO. 92 class use 721.388101578ms
# Import NO. 93 class use 1108.63304138ms
# Import NO. 94 class use 383.054971695ms
# Import NO. 95 class use 516.024112701ms
# Import NO. 96 class use 1327.95596123ms
# Import NO. 97 class use 575.416088104ms
# Import NO. 98 class use 842.785835266ms
# Import NO. 99 class use 508.499860764ms
# Import NO. 100 class use 233.465194702ms
# Import NO. 101 class use 374.722003937ms
# Import NO. 102 class use 189.170122147ms
# Import NO. 103 class use 1047.36089706ms
# Import NO. 104 class use 290.904998779ms
# Import NO. 105 class use 1189.74280357ms
# Import NO. 106 class use 596.393108368ms
# Import NO. 107 class use 551.772117615ms
# Import NO. 108 class use 545.590877533ms
# Import NO. 109 class use 926.433086395ms
# Import NO. 110 class use 480.090856552ms
# Import NO. 111 class use 271.539926529ms
# Import NO. 112 class use 402.699947357ms
# Import NO. 113 class use 1297.79791832ms
# Import NO. 114 class use 536.157846451ms
# Import NO. 115 class use 399.950027466ms
# Import NO. 116 class use 647.428035736ms
# Import NO. 117 class use 477.886915207ms
# Import NO. 118 class use 928.446769714ms
# Import NO. 119 class use 334.280014038ms
# Import NO. 120 class use 404.97803688ms
# Import NO. 121 class use 224.273920059ms
# Import NO. 122 class use 885.200977325ms
# Import NO. 123 class use 275.511980057ms
# Import NO. 124 class use 689.389944077ms
# Import NO. 125 class use 397.834062576ms
# Import NO. 126 class use 959.599971771ms
# Import NO. 127 class use 388.660907745ms
# Import NO. 128 class use 886.482000351ms
# Import NO. 129 class use 287.81414032ms
# Import NO. 130 class use 624.119997025ms
# Import NO. 131 class use 414.725780487ms
# Import NO. 132 class use 779.533863068ms
# Import NO. 133 class use 1050.32920837ms
# Import NO. 134 class use 469.769954681ms
# Import NO. 135 class use 364.726781845ms
# Import NO. 136 class use 792.737960815ms
# Import NO. 137 class use 830.705881119ms
# Import NO. 138 class use 1095.86501122ms
# Import NO. 139 class use 289.423942566ms
# Import NO. 140 class use 281.160831451ms
# Import NO. 141 class use 959.05995369ms
# Import NO. 142 class use 426.994085312ms
# Import NO. 143 class use 1019.0320015ms
# Import NO. 144 class use 686.151027679ms
# Import NO. 145 class use 1634.28592682ms
# Import NO. 146 class use 434.509992599ms
# Import NO. 147 class use 1076.41911507ms
# Import NO. 148 class use 605.544090271ms
# Import NO. 149 class use 384.690999985ms
# Import NO. 150 class use 925.086021423ms
# Import NO. 151 class use 505.625963211ms
# Import NO. 152 class use 832.664012909ms
# Import NO. 153 class use 216.898202896ms
# Import NO. 154 class use 905.590057373ms
# Import NO. 155 class use 368.611097336ms
# Import NO. 156 class use 242.689847946ms
# Import NO. 157 class use 324.70202446ms
# Import NO. 158 class use 1762.67910004ms
# Import NO. 159 class use 2051.76091194ms
# Import NO. 160 class use 299.041986465ms
# Import NO. 161 class use 352.075815201ms
# Import NO. 162 class use 704.301118851ms
# Import NO. 163 class use 409.613847733ms
# Import NO. 164 class use 680.335044861ms
# Import NO. 165 class use 606.570959091ms
# Import NO. 166 class use 436.101913452ms
# Import NO. 167 class use 420.185089111ms
# Import NO. 168 class use 631.695985794ms
# Import NO. 169 class use 566.163063049ms
# Import NO. 170 class use 1118.59989166ms
# Import NO. 171 class use 293.397903442ms
# Import NO. 172 class use 241.13202095ms
# Import NO. 173 class use 630.172967911ms
# Import NO. 174 class use 230.329990387ms
# Import NO. 175 class use 263.23390007ms
# Import NO. 176 class use 709.496974945ms
# Import NO. 177 class use 414.774179459ms
# Import NO. 178 class use 564.310073853ms
# Import NO. 179 class use 243.317127228ms
# Import NO. 180 class use 583.029031754ms
# Import NO. 181 class use 442.904949188ms
# Import NO. 182 class use 283.252000809ms
# Import NO. 183 class use 635.840177536ms
# Import NO. 184 class use 320.641040802ms
# Import NO. 185 class use 666.399002075ms
# Import NO. 186 class use 661.854982376ms
# Import NO. 187 class use 664.461135864ms
# Import NO. 188 class use 674.134969711ms
# Import NO. 189 class use 1132.05909729ms
# Import NO. 190 class use 969.783067703ms
# Import NO. 191 class use 349.477052689ms
# Import NO. 192 class use 832.740068436ms
# Import NO. 193 class use 567.848920822ms
# Import NO. 194 class use 676.070928574ms
# Import NO. 195 class use 465.124130249ms
# Import NO. 196 class use 479.869127274ms
# Import NO. 197 class use 556.647062302ms
# Import NO. 198 class use 1276.08704567ms
# Import NO. 199 class use 602.313041687ms
# Import NO. 200 class use 1013.32807541ms
# Import NO. 201 class use 227.202177048ms
# Import NO. 202 class use 737.354040146ms
# Import NO. 203 class use 397.232055664ms
# Import NO. 204 class use 221.332073212ms
# Import NO. 205 class use 386.216878891ms
# Import NO. 206 class use 410.399913788ms
# Import NO. 207 class use 1034.63387489ms
# Import NO. 208 class use 301.218986511ms
# Import NO. 209 class use 637.751102448ms
# Import NO. 210 class use 325.022935867ms
# Import NO. 211 class use 438.129901886ms
# Import NO. 212 class use 527.771949768ms
# Import NO. 213 class use 758.688211441ms
# Import NO. 214 class use 1074.79095459ms
# Import NO. 215 class use 512.979984283ms
# Import NO. 216 class use 293.650150299ms
# Import NO. 217 class use 599.388122559ms
# Import NO. 218 class use 250.439167023ms
# Import NO. 219 class use 455.253124237ms
# Import NO. 220 class use 296.383857727ms
# Import NO. 221 class use 822.030067444ms
# Import NO. 222 class use 599.917888641ms
# Import NO. 223 class use 264.538049698ms
# Import NO. 224 class use 744.942903519ms
# Import NO. 225 class use 380.483865738ms
# Import NO. 226 class use 1003.05891037ms
# Import NO. 227 class use 762.431144714ms
# Import NO. 228 class use 828.314065933ms
# Import NO. 229 class use 1000.20003319ms
# Import NO. 230 class use 255.146980286ms
# Import NO. 231 class use 501.477956772ms
# Import NO. 232 class use 1982.40995407ms
# Import NO. 233 class use 584.25784111ms
# Import NO. 234 class use 275.943040848ms
# Import NO. 235 class use 347.55396843ms
# Import NO. 236 class use 769.861936569ms
# Import NO. 237 class use 606.92691803ms
# Import NO. 238 class use 239.864110947ms
# Import NO. 239 class use 536.328077316ms
# Import NO. 240 class use 479.403018951ms
# Import NO. 241 class use 1168.04003716ms
# Import NO. 242 class use 670.45211792ms
# Import NO. 243 class use 340.358018875ms
# Import NO. 244 class use 670.865058899ms
# Import NO. 245 class use 428.851127625ms
# Import NO. 246 class use 301.655054092ms
# Import NO. 247 class use 441.325187683ms
# Import NO. 248 class use 277.245044708ms
# Import NO. 249 class use 621.999025345ms
# Import NO. 250 class use 841.563940048ms
# Import NO. 251 class use 1768.53704453ms
# Import NO. 252 class use 200.098991394ms
# Import NO. 253 class use 1323.66204262ms
# Import NO. 254 class use 513.68188858ms
# Import NO. 255 class use 392.805099487ms
# Import NO. 256 class use 903.398036957ms

# %%
print('Total number of datasets: ' + str(len(data_set)))
print('Total number of classes: ' + str(len(dict_label)))
# Out:
# Total number of datasets: 29782
# Total number of classes: 256

# %%
plt.imshow(data_set[0][1])
print('This picture is ' + dict_label[0])
# Out:
# This picture is ak47

# %%
#Save dataset and class dict
np.save('orig_data.npy', data_set)
