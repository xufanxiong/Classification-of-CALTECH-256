# %%
import keras
from keras.applications import DenseNet169 #DenseNet121, DenseNet169, DenseNet201, ResNet50
from keras.models import Model
from keras.layers import Dense
from keras.regularizers import l2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from label2onehot import label2onehot
from onehot2label import onehot2label
from label_dict import label_dict
import gc
# Out:
# /opt/conda/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Use GPU
config = tf.ConfigProto( device_count = {'GPU': 2 , 'CPU': 4}, log_device_placement=True ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)

# %%
#Import train set
x = np.load('train_resize_221.npy')/255.
y_label = np.load('train.npy')

# %%
#Convert label to onehot
#onehot_y = label2onehot(y[:, 0], 256)
#np.save('onehot_y_train.npy',onehot_y)
#from keras.utils.np_utils import to_categorical
#y = to_categorical(y_label[:,0], num_classes=256)
y = y_label[:,0]

# %%
#Build the new model based on DenseNet121
def getmodel(num_classes=256):
    '''
    Build the new model based on DenseNet121, DenseNet169, DenseNet201
    
    Argument:
    num_classes -- (int) number of classes
    
    Return:
    model -- the new compiled model
    '''
    
    orig_model = DenseNet169(include_top=False, weights='imagenet', pooling='avg', classes=num_classes)
    densenet_out = orig_model.layers[-1].output
    out = Dense(256, activation='softmax', kernel_initializer='glorot_uniform')(densenet_out)
    model = Model(input=orig_model.input, output=out)
    model.compile(loss= "sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    
    return model

# %%
densemodel = getmodel(256)
# checkpoint
from keras.callbacks import ModelCheckpoint
filepath="DenseNet169_transfer.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True,mode='max')
callbacks_list = [checkpoint]
history = densemodel.fit(x, y, epochs=30, batch_size=32, validation_split=0.25, callbacks=callbacks_list)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
#   app.launch_new_instance()
# Train on 17868 samples, validate on 5956 samples
# Epoch 1/30
# 17868/17868 [==============================] - 283s 16ms/step - loss: 3.2011 - acc: 0.3271 - val_loss: 3.4806 - val_acc: 0.3428
#
# Epoch 00001: val_acc improved from -inf to 0.34285, saving model to DenseNet169_transfer.hdf5
# Epoch 2/30
# 17868/17868 [==============================] - 258s 14ms/step - loss: 1.7828 - acc: 0.5726 - val_loss: 2.8855 - val_acc: 0.4547
#
# Epoch 00002: val_acc improved from 0.34285 to 0.45467, saving model to DenseNet169_transfer.hdf5
# Epoch 3/30
# 17868/17868 [==============================] - 256s 14ms/step - loss: 1.2676 - acc: 0.6787 - val_loss: 2.5263 - val_acc: 0.4768
#
# Epoch 00003: val_acc improved from 0.45467 to 0.47683, saving model to DenseNet169_transfer.hdf5
# Epoch 4/30
# 17868/17868 [==============================] - 255s 14ms/step - loss: 0.8966 - acc: 0.7600 - val_loss: 2.4226 - val_acc: 0.5143
#
# Epoch 00004: val_acc improved from 0.47683 to 0.51427, saving model to DenseNet169_transfer.hdf5
# Epoch 5/30
# 17868/17868 [==============================] - 255s 14ms/step - loss: 0.6422 - acc: 0.8209 - val_loss: 2.9163 - val_acc: 0.4849
#
# Epoch 00005: val_acc did not improve
# Epoch 6/30
# 17868/17868 [==============================] - 254s 14ms/step - loss: 0.4628 - acc: 0.8652 - val_loss: 2.4108 - val_acc: 0.5598
#
# Epoch 00006: val_acc improved from 0.51427 to 0.55977, saving model to DenseNet169_transfer.hdf5
# Epoch 7/30
# 17868/17868 [==============================] - 255s 14ms/step - loss: 0.3323 - acc: 0.9004 - val_loss: 2.7902 - val_acc: 0.5250
#
# Epoch 00007: val_acc did not improve
# Epoch 8/30
# 17868/17868 [==============================] - 254s 14ms/step - loss: 0.2969 - acc: 0.9128 - val_loss: 3.0661 - val_acc: 0.5252
#
# Epoch 00008: val_acc did not improve
# Epoch 9/30
# 17868/17868 [==============================] - 254s 14ms/step - loss: 0.2840 - acc: 0.9167 - val_loss: 2.5884 - val_acc: 0.5772
#
# Epoch 00009: val_acc improved from 0.55977 to 0.57723, saving model to DenseNet169_transfer.hdf5
# Epoch 10/30
# 17868/17868 [==============================] - 253s 14ms/step - loss: 0.2716 - acc: 0.9171 - val_loss: 3.6641 - val_acc: 0.4945
#
# Epoch 00010: val_acc did not improve
# Epoch 11/30
# 17868/17868 [==============================] - 254s 14ms/step - loss: 0.2017 - acc: 0.9396 - val_loss: 3.4650 - val_acc: 0.4988
#
# Epoch 00011: val_acc did not improve
# Epoch 12/30
# 17868/17868 [==============================] - 254s 14ms/step - loss: 0.1720 - acc: 0.9468 - val_loss: 2.6671 - val_acc: 0.5601
#
# Epoch 00012: val_acc did not improve
# Epoch 13/30
# 17868/17868 [==============================] - 255s 14ms/step - loss: 0.1963 - acc: 0.9415 - val_loss: 3.2033 - val_acc: 0.5468
#
# Epoch 00013: val_acc did not improve
# Epoch 14/30
# 17868/17868 [==============================] - 257s 14ms/step - loss: 0.1880 - acc: 0.9395 - val_loss: 2.5981 - val_acc: 0.5981
#
# Epoch 00014: val_acc improved from 0.57723 to 0.59805, saving model to DenseNet169_transfer.hdf5
# Epoch 15/30
# 17868/17868 [==============================] - 258s 14ms/step - loss: 0.1420 - acc: 0.9566 - val_loss: 3.6902 - val_acc: 0.5233
#
# Epoch 00015: val_acc did not improve
# Epoch 16/30
# 17868/17868 [==============================] - 258s 14ms/step - loss: 0.1632 - acc: 0.9515 - val_loss: 3.9959 - val_acc: 0.4579
#
# Epoch 00016: val_acc did not improve
# Epoch 17/30
# 17868/17868 [==============================] - 257s 14ms/step - loss: 0.1518 - acc: 0.9538 - val_loss: 2.8482 - val_acc: 0.5831
#
# Epoch 00017: val_acc did not improve
# Epoch 18/30
# 17868/17868 [==============================] - 257s 14ms/step - loss: 0.1321 - acc: 0.9582 - val_loss: 2.7241 - val_acc: 0.5917
#
# Epoch 00018: val_acc did not improve
# Epoch 19/30
# 17868/17868 [==============================] - 257s 14ms/step - loss: 0.1010 - acc: 0.9691 - val_loss: 2.8072 - val_acc: 0.5954
#
# Epoch 00019: val_acc did not improve
# Epoch 20/30
# 17868/17868 [==============================] - 259s 14ms/step - loss: 0.1640 - acc: 0.9499 - val_loss: 3.3977 - val_acc: 0.5319
#
# Epoch 00020: val_acc did not improve
# Epoch 21/30
# 17868/17868 [==============================] - 259s 15ms/step - loss: 0.1443 - acc: 0.9552 - val_loss: 3.2566 - val_acc: 0.5576
#
# Epoch 00021: val_acc did not improve
# Epoch 22/30
# 17868/17868 [==============================] - 259s 15ms/step - loss: 0.0923 - acc: 0.9727 - val_loss: 3.7724 - val_acc: 0.5175
#
# Epoch 00022: val_acc did not improve
# Epoch 23/30
# 17868/17868 [==============================] - 257s 14ms/step - loss: 0.0830 - acc: 0.9758 - val_loss: 3.3615 - val_acc: 0.5490
#
# Epoch 00023: val_acc did not improve
# Epoch 24/30
# 17868/17868 [==============================] - 257s 14ms/step - loss: 0.1396 - acc: 0.9579 - val_loss: 2.8633 - val_acc: 0.5858
#
# Epoch 00024: val_acc did not improve
# Epoch 25/30
# 17868/17868 [==============================] - 257s 14ms/step - loss: 0.1135 - acc: 0.9653 - val_loss: 3.8785 - val_acc: 0.5207
#
# Epoch 00025: val_acc did not improve
# Epoch 26/30
# 17868/17868 [==============================] - 258s 14ms/step - loss: 0.0944 - acc: 0.9706 - val_loss: 3.1134 - val_acc: 0.5625
#
# Epoch 00026: val_acc did not improve
# Epoch 27/30
# 17868/17868 [==============================] - 259s 14ms/step - loss: 0.1092 - acc: 0.9660 - val_loss: 3.1108 - val_acc: 0.5735
#
# Epoch 00027: val_acc did not improve
# Epoch 28/30
# 17868/17868 [==============================] - 258s 14ms/step - loss: 0.0862 - acc: 0.9711 - val_loss: 2.7417 - val_acc: 0.6229
#
# Epoch 00028: val_acc improved from 0.59805 to 0.62290, saving model to DenseNet169_transfer.hdf5
# Epoch 29/30
# 17868/17868 [==============================] - 259s 14ms/step - loss: 0.0946 - acc: 0.9706 - val_loss: 3.2147 - val_acc: 0.5771
#
# Epoch 00029: val_acc did not improve
# Epoch 30/30
# 17868/17868 [==============================] - 258s 14ms/step - loss: 0.1223 - acc: 0.9637 - val_loss: 3.0780 - val_acc: 0.5920
#
# Epoch 00030: val_acc did not improve

# %%
#release RAM
del x, y
gc.collect()
# Out:
# 15

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Import test dataset
X_test = np.load('test_resize_221.npy')/255.
Y_test = np.load('onehot_y_test.npy')
y_test = np.load('test.npy')

# %%
##Convert label to onehot
#y_test = label2onehot(Y_test[:, 0], 256)
#np.save('onehot_y_test.npy', y_test)

# %%
densemodel.load_weights('DenseNet169_transfer.hdf5')

# %%
#evaluate
eva = densemodel.evaluate(X_test, y_test[:, 0], batch_size=32, verbose=1, sample_weight=None)
print()
print("Loss = " + str(eva[0]))
print("Test Accuracy = " + str(eva[1]))
# Out:
# 5956/5956 [==============================] - 35s 6ms/step
# ()
# Loss = 2.745211417920002
# Test Accuracy = 0.6168569509738079

# %%
#predict a new image
predict_num = 2500
dict_label = label_dict()
X_predict = X_test[predict_num]
print('This image is: ' + dict_label[y_test[:, 0][predict_num]+1])
print('The dict_label of image is: '+str(y_test[:, 0][predict_num]+1))
plt.imshow(X_predict)
# Out:
# This image is: covered-wagon
# The dict_label of image is: 50

# %%
#predict
predict_vector = densemodel.predict(np.expand_dims(X_predict, axis=0))
index = np.where(predict_vector[0] == np.max(predict_vector[0]))
print('The predict dict_label of image is: '+str(index[0][0]+1))
print('The predict probability of image is: '+str(predict_vector[0, index[0][0]]))
print('This image is: ' + dict_label[index[0][0] + 1])
# Out:
# The predict dict_label of image is: 50
# The predict probability of image is: 1.0
# This image is: covered-wagon

# %%
#densemodel.save_weights('DenseNet169_transfer.hdf5')
