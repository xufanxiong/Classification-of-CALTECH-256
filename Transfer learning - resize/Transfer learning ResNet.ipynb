# %%
import keras
from keras.applications import ResNet50 #DenseNet121, DenseNet169, DenseNet201, ResNet50
from keras.models import Model
from keras.layers import Dense
from keras.regularizers import l2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from label2onehot import label2onehot
from onehot2label import onehot2label
from label_dict import label_dict
import gc
# Out:
# /opt/conda/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Use GPU
config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 4}, log_device_placement=True ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)

# %%
#Import train set
x = np.load('train_resize_221.npy')/255.
y_label = np.load('train.npy')

# %%
#Convert label to onehot
#onehot_y = label2onehot(y[:, 0], 256)
#np.save('onehot_y_train.npy',onehot_y)
#from keras.utils.np_utils import to_categorical
#y = to_categorical(y_label[:,0], num_classes=256)
y = y_label[:,0]

# %%
#Build the new model based on DenseNet121
def getmodel(num_classes=256):
    '''
    Build the new model based on DenseNet121, DenseNet169, DenseNet201
    
    Argument:
    num_classes -- (int) number of classes
    
    Return:
    model -- the new compiled model
    '''
    
    orig_model = ResNet50(include_top=False, weights='imagenet', pooling='avg', classes=num_classes)
    densenet_out = orig_model.layers[-1].output
    out = Dense(256, activation='softmax', kernel_initializer='glorot_uniform')(densenet_out)
    model = Model(input=orig_model.input, output=out)
    model.compile(loss= "sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    
    return model

# %%
densemodel = getmodel(256)
# checkpoint
from keras.callbacks import ModelCheckpoint
filepath="ResNet50_transfer.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True,mode='max')
callbacks_list = [checkpoint]
history = densemodel.fit(x, y, epochs=30, batch_size=32, validation_split=0.25, callbacks=callbacks_list)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
#   app.launch_new_instance()
# Train on 17868 samples, validate on 5956 samples
# Epoch 1/30
# 17868/17868 [==============================] - 192s 11ms/step - loss: 4.0365 - acc: 0.2018 - val_loss: 6.8593 - val_acc: 0.0757
#
# Epoch 00001: val_acc improved from -inf to 0.07572, saving model to ResNet50_transfer.hdf5
# Epoch 2/30
# 17868/17868 [==============================] - 183s 10ms/step - loss: 2.3564 - acc: 0.4566 - val_loss: 3.0719 - val_acc: 0.3370
#
# Epoch 00002: val_acc improved from 0.07572 to 0.33697, saving model to ResNet50_transfer.hdf5
# Epoch 3/30
# 17868/17868 [==============================] - 183s 10ms/step - loss: 1.5772 - acc: 0.6076 - val_loss: 2.8113 - val_acc: 0.3781
#
# Epoch 00003: val_acc improved from 0.33697 to 0.37811, saving model to ResNet50_transfer.hdf5
# Epoch 4/30
# 17868/17868 [==============================] - 182s 10ms/step - loss: 1.0300 - acc: 0.7344 - val_loss: 2.6403 - val_acc: 0.4458
#
# Epoch 00004: val_acc improved from 0.37811 to 0.44577, saving model to ResNet50_transfer.hdf5
# Epoch 5/30
# 17868/17868 [==============================] - 182s 10ms/step - loss: 0.6109 - acc: 0.8337 - val_loss: 2.8900 - val_acc: 0.4297
#
# Epoch 00005: val_acc did not improve
# Epoch 6/30
# 17868/17868 [==============================] - 184s 10ms/step - loss: 0.3413 - acc: 0.9072 - val_loss: 2.8374 - val_acc: 0.4762
#
# Epoch 00006: val_acc improved from 0.44577 to 0.47616, saving model to ResNet50_transfer.hdf5
# Epoch 7/30
# 17868/17868 [==============================] - 186s 10ms/step - loss: 0.2127 - acc: 0.9405 - val_loss: 2.6115 - val_acc: 0.5225
#
# Epoch 00007: val_acc improved from 0.47616 to 0.52250, saving model to ResNet50_transfer.hdf5
# Epoch 8/30
# 17868/17868 [==============================] - 188s 11ms/step - loss: 0.1883 - acc: 0.9469 - val_loss: 3.1258 - val_acc: 0.4283
#
# Epoch 00008: val_acc did not improve
# Epoch 9/30
# 17868/17868 [==============================] - 185s 10ms/step - loss: 0.1628 - acc: 0.9555 - val_loss: 3.5573 - val_acc: 0.3912
#
# Epoch 00009: val_acc did not improve
# Epoch 10/30
# 17868/17868 [==============================] - 187s 10ms/step - loss: 0.1450 - acc: 0.9577 - val_loss: 2.8766 - val_acc: 0.4869
#
# Epoch 00010: val_acc did not improve
# Epoch 11/30
# 17868/17868 [==============================] - 188s 11ms/step - loss: 0.1196 - acc: 0.9666 - val_loss: 2.6354 - val_acc: 0.5176
#
# Epoch 00011: val_acc did not improve
# Epoch 12/30
# 17868/17868 [==============================] - 190s 11ms/step - loss: 0.1029 - acc: 0.9721 - val_loss: 3.4503 - val_acc: 0.4461
#
# Epoch 00012: val_acc did not improve
# Epoch 13/30
# 17868/17868 [==============================] - 190s 11ms/step - loss: 0.1083 - acc: 0.9693 - val_loss: 2.7266 - val_acc: 0.5107
#
# Epoch 00013: val_acc did not improve
# Epoch 14/30
# 17868/17868 [==============================] - 188s 11ms/step - loss: 0.0965 - acc: 0.9729 - val_loss: 3.9835 - val_acc: 0.4189
#
# Epoch 00014: val_acc did not improve
# Epoch 15/30
# 17868/17868 [==============================] - 184s 10ms/step - loss: 0.0735 - acc: 0.9804 - val_loss: 3.0815 - val_acc: 0.5057
#
# Epoch 00015: val_acc did not improve
# Epoch 16/30
# 17868/17868 [==============================] - 184s 10ms/step - loss: 0.0945 - acc: 0.9730 - val_loss: 3.6929 - val_acc: 0.3739
#
# Epoch 00016: val_acc did not improve
# Epoch 17/30
# 17868/17868 [==============================] - 184s 10ms/step - loss: 0.0749 - acc: 0.9788 - val_loss: 3.8136 - val_acc: 0.4384
#
# Epoch 00017: val_acc did not improve
# Epoch 18/30
# 17868/17868 [==============================] - 183s 10ms/step - loss: 0.0677 - acc: 0.9818 - val_loss: 2.9374 - val_acc: 0.5136
#
# Epoch 00018: val_acc did not improve
# Epoch 19/30
# 17868/17868 [==============================] - 181s 10ms/step - loss: 0.0852 - acc: 0.9749 - val_loss: 2.7923 - val_acc: 0.5403
#
# Epoch 00019: val_acc improved from 0.52250 to 0.54030, saving model to ResNet50_transfer.hdf5
# Epoch 20/30
# 17868/17868 [==============================] - 182s 10ms/step - loss: 0.0541 - acc: 0.9856 - val_loss: 3.2412 - val_acc: 0.4770
#
# Epoch 00020: val_acc did not improve
# Epoch 21/30
# 17868/17868 [==============================] - 181s 10ms/step - loss: 0.0277 - acc: 0.9937 - val_loss: 2.8704 - val_acc: 0.5351
#
# Epoch 00021: val_acc did not improve
# Epoch 22/30
# 17868/17868 [==============================] - 183s 10ms/step - loss: 0.0734 - acc: 0.9790 - val_loss: 3.8636 - val_acc: 0.4505
#
# Epoch 00022: val_acc did not improve
# Epoch 23/30
# 17868/17868 [==============================] - 186s 10ms/step - loss: 0.0528 - acc: 0.9849 - val_loss: 2.9537 - val_acc: 0.5212
#
# Epoch 00023: val_acc did not improve
# Epoch 24/30
# 17868/17868 [==============================] - 186s 10ms/step - loss: 0.0677 - acc: 0.9801 - val_loss: 3.4384 - val_acc: 0.4718
#
# Epoch 00024: val_acc did not improve
# Epoch 25/30
# 17868/17868 [==============================] - 185s 10ms/step - loss: 0.0385 - acc: 0.9896 - val_loss: 3.1746 - val_acc: 0.5351
#
# Epoch 00025: val_acc did not improve
# Epoch 26/30
# 17868/17868 [==============================] - 184s 10ms/step - loss: 0.0515 - acc: 0.9863 - val_loss: 3.5100 - val_acc: 0.4919
#
# Epoch 00026: val_acc did not improve
# Epoch 27/30
# 17868/17868 [==============================] - 185s 10ms/step - loss: 0.0436 - acc: 0.9881 - val_loss: 4.1859 - val_acc: 0.3833
#
# Epoch 00027: val_acc did not improve
# Epoch 28/30
# 17868/17868 [==============================] - 182s 10ms/step - loss: 0.0365 - acc: 0.9896 - val_loss: 3.5410 - val_acc: 0.4698
#
# Epoch 00028: val_acc did not improve
# Epoch 29/30
# 17868/17868 [==============================] - 183s 10ms/step - loss: 0.0395 - acc: 0.9895 - val_loss: 3.7263 - val_acc: 0.4715
#
# Epoch 00029: val_acc did not improve
# Epoch 30/30
# 17868/17868 [==============================] - 186s 10ms/step - loss: 0.0497 - acc: 0.9861 - val_loss: 3.0064 - val_acc: 0.5200
#
# Epoch 00030: val_acc did not improve

# %%
#release RAM
del x, y
gc.collect()
# Out:
# 7868

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Import test dataset
X_test = np.load('test_resize_221.npy')/255.
Y_test = np.load('onehot_y_test.npy')
y_test = np.load('test.npy')

# %%
##Convert label to onehot
#y_test = label2onehot(Y_test[:, 0], 256)
#np.save('onehot_y_test.npy', y_test)

# %%
densemodel.load_weights('ResNet50_transfer.hdf5')

# %%
#evaluate
eva = densemodel.evaluate(X_test, y_test[:, 0], batch_size=32, verbose=1, sample_weight=None)
print()
print("Loss = " + str(eva[0]))
print("Test Accuracy = " + str(eva[1]))
# Out:
# 5956/5956 [==============================] - 23s 4ms/step
# ()
# Loss = 2.8057488251885285
# Test Accuracy = 0.5421423774345198

# %%
#predict a new image
predict_num = 1111
dict_label = label_dict()
X_predict = X_test[predict_num]
print('This image is: ' + dict_label[y_test[:, 0][predict_num]+1])
print('The dict_label of image is: '+str(y_test[:, 0][predict_num]+1))
plt.imshow(X_predict)
# Out:
# This image is: diamond-ring
# The dict_label of image is: 54

# %%
#predict
predict_vector = densemodel.predict(np.expand_dims(X_predict, axis=0))
index = np.where(predict_vector[0] == np.max(predict_vector[0]))
print('The predict dict_label of image is: '+str(index[0][0]+1))
print('The predict probability of image is: '+str(predict_vector[0, index[0][0]]))
print('This image is: ' + dict_label[index[0][0] + 1])
# Out:
# The predict dict_label of image is: 54
# The predict probability of image is: 0.99998343
# This image is: diamond-ring

# %%
#densemodel.save_weights('ResNet50_transfer.hdf5')
