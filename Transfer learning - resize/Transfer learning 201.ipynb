# %%
import keras
from keras.applications import DenseNet201 #DenseNet121, DenseNet169, DenseNet201, ResNet50
from keras.models import Model
from keras.layers import Dense
from keras.regularizers import l2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from label2onehot import label2onehot
from onehot2label import onehot2label
from label_dict import label_dict
import gc
# Out:
# /opt/conda/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Use GPU
config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 4}, log_device_placement=True ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)

# %%
#Import train set
x = np.load('train_resize_221.npy')/255.
y_label = np.load('train.npy')

# %%
#Convert label to onehot
#onehot_y = label2onehot(y[:, 0], 256)
#np.save('onehot_y_train.npy',onehot_y)
#from keras.utils.np_utils import to_categorical
#y = to_categorical(y_label[:,0], num_classes=256)
y = y_label[:,0]

# %%
#Build the new model based on DenseNet121
def getmodel(num_classes=256):
    '''
    Build the new model based on DenseNet121, DenseNet169, DenseNet201
    
    Argument:
    num_classes -- (int) number of classes
    
    Return:
    model -- the new compiled model
    '''
    
    orig_model = DenseNet201(include_top=False, weights='imagenet', pooling='avg', classes=num_classes)
    densenet_out = orig_model.layers[-1].output
    out = Dense(256, activation='softmax', kernel_initializer='glorot_uniform')(densenet_out)
    model = Model(input=orig_model.input, output=out)
    model.compile(loss= "sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    
    return model

# %%
densemodel = getmodel(256)
# checkpoint
from keras.callbacks import ModelCheckpoint
filepath="DenseNet201_transfer.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True,mode='max')
callbacks_list = [checkpoint]
history = densemodel.fit(x, y, epochs=30, batch_size=32, validation_split=0.25, callbacks=callbacks_list)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
#   app.launch_new_instance()
# Train on 17868 samples, validate on 5956 samples
# Epoch 1/30
# 17868/17868 [==============================] - 355s 20ms/step - loss: 3.1446 - acc: 0.3323 - val_loss: 7.1547 - val_acc: 0.1837
#
# Epoch 00001: val_acc improved from -inf to 0.18368, saving model to DenseNet201_transfer.hdf5
# Epoch 2/30
# 17868/17868 [==============================] - 322s 18ms/step - loss: 1.7858 - acc: 0.5684 - val_loss: 2.6681 - val_acc: 0.4607
#
# Epoch 00002: val_acc improved from 0.18368 to 0.46071, saving model to DenseNet201_transfer.hdf5
# Epoch 3/30
# 17868/17868 [==============================] - 325s 18ms/step - loss: 1.2475 - acc: 0.6817 - val_loss: 2.7844 - val_acc: 0.4740
#
# Epoch 00003: val_acc improved from 0.46071 to 0.47398, saving model to DenseNet201_transfer.hdf5
# Epoch 4/30
# 17868/17868 [==============================] - 322s 18ms/step - loss: 0.9074 - acc: 0.7601 - val_loss: 2.6111 - val_acc: 0.4948
#
# Epoch 00004: val_acc improved from 0.47398 to 0.49480, saving model to DenseNet201_transfer.hdf5
# Epoch 5/30
# 17868/17868 [==============================] - 322s 18ms/step - loss: 0.6746 - acc: 0.8140 - val_loss: 2.4976 - val_acc: 0.5463
#
# Epoch 00005: val_acc improved from 0.49480 to 0.54634, saving model to DenseNet201_transfer.hdf5
# Epoch 6/30
# 17868/17868 [==============================] - 325s 18ms/step - loss: 0.4780 - acc: 0.8648 - val_loss: 2.4486 - val_acc: 0.5408
#
# Epoch 00006: val_acc did not improve
# Epoch 7/30
# 17868/17868 [==============================] - 324s 18ms/step - loss: 0.3263 - acc: 0.9009 - val_loss: 2.7383 - val_acc: 0.5393
#
# Epoch 00007: val_acc did not improve
# Epoch 8/30
# 17868/17868 [==============================] - 323s 18ms/step - loss: 0.3104 - acc: 0.9080 - val_loss: 2.4087 - val_acc: 0.5611
#
# Epoch 00008: val_acc improved from 0.54634 to 0.56111, saving model to DenseNet201_transfer.hdf5
# Epoch 9/30
# 17868/17868 [==============================] - 321s 18ms/step - loss: 0.2724 - acc: 0.9192 - val_loss: 2.9823 - val_acc: 0.5468
#
# Epoch 00009: val_acc did not improve
# Epoch 10/30
# 17868/17868 [==============================] - 332s 19ms/step - loss: 0.2415 - acc: 0.9267 - val_loss: 2.6386 - val_acc: 0.5573
#
# Epoch 00010: val_acc did not improve
# Epoch 11/30
# 17868/17868 [==============================] - 338s 19ms/step - loss: 0.2258 - acc: 0.9317 - val_loss: 2.7194 - val_acc: 0.5531
#
# Epoch 00011: val_acc did not improve
# Epoch 12/30
# 17868/17868 [==============================] - 337s 19ms/step - loss: 0.1983 - acc: 0.9389 - val_loss: 4.9133 - val_acc: 0.3685
#
# Epoch 00012: val_acc did not improve
# Epoch 13/30
# 17868/17868 [==============================] - 339s 19ms/step - loss: 0.1987 - acc: 0.9384 - val_loss: 2.7478 - val_acc: 0.5608
#
# Epoch 00013: val_acc did not improve
# Epoch 14/30
# 17868/17868 [==============================] - 338s 19ms/step - loss: 0.1836 - acc: 0.9460 - val_loss: 3.2482 - val_acc: 0.5107
#
# Epoch 00014: val_acc did not improve
# Epoch 15/30
# 17868/17868 [==============================] - 335s 19ms/step - loss: 0.1419 - acc: 0.9560 - val_loss: 3.0197 - val_acc: 0.5583
#
# Epoch 00015: val_acc did not improve
# Epoch 16/30
# 17868/17868 [==============================] - 335s 19ms/step - loss: 0.1711 - acc: 0.9492 - val_loss: 2.8643 - val_acc: 0.5557
#
# Epoch 00016: val_acc did not improve
# Epoch 17/30
# 17868/17868 [==============================] - 332s 19ms/step - loss: 0.1511 - acc: 0.9530 - val_loss: 2.9036 - val_acc: 0.5813
#
# Epoch 00017: val_acc improved from 0.56111 to 0.58126, saving model to DenseNet201_transfer.hdf5
# Epoch 18/30
# 17868/17868 [==============================] - 330s 18ms/step - loss: 0.1030 - acc: 0.9687 - val_loss: 3.1847 - val_acc: 0.5368
#
# Epoch 00018: val_acc did not improve
# Epoch 19/30
# 17868/17868 [==============================] - 329s 18ms/step - loss: 0.1420 - acc: 0.9562 - val_loss: 2.9572 - val_acc: 0.5640
#
# Epoch 00019: val_acc did not improve
# Epoch 20/30
# 17868/17868 [==============================] - 334s 19ms/step - loss: 0.1356 - acc: 0.9581 - val_loss: 2.8195 - val_acc: 0.5947
#
# Epoch 00020: val_acc improved from 0.58126 to 0.59469, saving model to DenseNet201_transfer.hdf5
# Epoch 21/30
# 17868/17868 [==============================] - 336s 19ms/step - loss: 0.1203 - acc: 0.9628 - val_loss: 3.1842 - val_acc: 0.5571
#
# Epoch 00021: val_acc did not improve
# Epoch 22/30
# 17868/17868 [==============================] - 340s 19ms/step - loss: 0.1193 - acc: 0.9623 - val_loss: 2.9979 - val_acc: 0.5776
#
# Epoch 00022: val_acc did not improve
# Epoch 23/30
# 17868/17868 [==============================] - 340s 19ms/step - loss: 0.1204 - acc: 0.9630 - val_loss: 2.9401 - val_acc: 0.5856
#
# Epoch 00023: val_acc did not improve
# Epoch 24/30
# 17868/17868 [==============================] - 337s 19ms/step - loss: 0.1087 - acc: 0.9665 - val_loss: 4.2024 - val_acc: 0.4898
#
# Epoch 00024: val_acc did not improve
# Epoch 25/30
# 17868/17868 [==============================] - 337s 19ms/step - loss: 0.0865 - acc: 0.9743 - val_loss: 2.9446 - val_acc: 0.5944
#
# Epoch 00025: val_acc did not improve
# Epoch 26/30
# 17868/17868 [==============================] - 337s 19ms/step - loss: 0.1103 - acc: 0.9657 - val_loss: 3.4317 - val_acc: 0.5443
#
# Epoch 00026: val_acc did not improve
# Epoch 27/30
# 17868/17868 [==============================] - 337s 19ms/step - loss: 0.1085 - acc: 0.9660 - val_loss: 3.1385 - val_acc: 0.5893
#
# Epoch 00027: val_acc did not improve
# Epoch 28/30
# 17868/17868 [==============================] - 327s 18ms/step - loss: 0.0968 - acc: 0.9698 - val_loss: 3.3815 - val_acc: 0.5546
#
# Epoch 00028: val_acc did not improve
# Epoch 29/30
# 17868/17868 [==============================] - 326s 18ms/step - loss: 0.0766 - acc: 0.9752 - val_loss: 3.1700 - val_acc: 0.5928
#
# Epoch 00029: val_acc did not improve
# Epoch 30/30
# 17868/17868 [==============================] - 323s 18ms/step - loss: 0.0928 - acc: 0.9716 - val_loss: 2.9474 - val_acc: 0.5975
#
# Epoch 00030: val_acc improved from 0.59469 to 0.59755, saving model to DenseNet201_transfer.hdf5

# %%
#release RAM
del x, y
gc.collect()
# Out:
# 21873

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Import test dataset
X_test = np.load('test_resize_221.npy')/255.
Y_test = np.load('onehot_y_test.npy')
y_test = np.load('test.npy')

# %%
##Convert label to onehot
#y_test = label2onehot(Y_test[:, 0], 256)
#np.save('onehot_y_test.npy', y_test)

# %%
densemodel.load_weights('DenseNet201_transfer.hdf5')

# %%
#evaluate
eva = densemodel.evaluate(X_test, y_test[:, 0], batch_size=32, verbose=1, sample_weight=None)
print()
print("Loss = " + str(eva[0]))
print("Test Accuracy = " + str(eva[1]))
# Out:
# 5956/5956 [==============================] - 40s 7ms/step
# ()
# Loss = 2.9334559469434383
# Test Accuracy = 0.5938549361987912

# %%
#predict a new image
predict_num = 1111
dict_label = label_dict()
X_predict = X_test[predict_num]
print('This image is: ' + dict_label[y_test[:, 0][predict_num]+1])
print('The dict_label of image is: '+str(y_test[:, 0][predict_num]+1))
plt.imshow(X_predict)
# Out:
# This image is: diamond-ring
# The dict_label of image is: 54

# %%
#predict
predict_vector = densemodel.predict(np.expand_dims(X_predict, axis=0))
index = np.where(predict_vector[0] == np.max(predict_vector[0]))
print('The predict dict_label of image is: '+str(index[0][0]+1))
print('The predict probability of image is: '+str(predict_vector[0, index[0][0]]))
print('This image is: ' + dict_label[index[0][0] + 1])
# Out:
# The predict dict_label of image is: 54
# The predict probability of image is: 1.0
# This image is: diamond-ring

# %%
#densemodel.save_weights('DenseNet201_transfer.hdf5')
